# %% [markdown]
# # nqueens-recog — Hello World
#
# This notebook demonstrates the basic project structure and a simple greeting function.

# %%
import sys
import os

# Make the src package importable when running from the notebooks/ directory
sys.path.insert(0, os.path.join(os.path.dirname(os.path.abspath('__file__')), '..', 'src'))

# %%
from nqueens_recog import greet

message = greet()
print(message)
# Out:
# Hello, World! Welcome to nqueens-recog.

# %%
# Try with a custom name
print(greet("N-Queens Solver"))
# Out:
# Hello, N-Queens Solver! Welcome to nqueens-recog.
